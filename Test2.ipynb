# %% [markdown]
# # TEST:-
# 10/07/024

# %% [markdown]
# 1.Load data set and perform all da visualisation graphs.
#
# 2.Explain OOP and perform one example with method.
#
# 3.Explain type of Inheritance And perform Single inheritance example.
#
# 4.Explain and perform Al built in data types in python.
#
# 5.What is training set and 'Test set' in Machin Learning model? How much data will you allocated for Your Traning validatin and test set
#
# 6.How do you handle Missing and Computed data in data set?
#
# 7.Compare K-means and KNN Algorithms.
#
# 8.What is SQL, Explain DDL,DML,TCL,DQL command in sql.
#
# 9.What are the constraint use in SQL?
#
# 10.Explain difference between Primary key, Foriegn key and Unique key in SQL?

# %% [markdown]
# ## 2.Explain OOP and perform one example with method.
# ### OOPs:- Object Oriented Programming System.
# ### Type:-
#       1.Class
#
#       2.Object
#
#       3.Inheritance
#
#       4.Abstrction

# %%
#ex. 1.Class: it is collection of data
class student:
    def stu(id,name,marks):
      print('stu id:',id)
      print('stu name:',name)
      print('stu marks:',marks)
student.stu(1,'Sonali',80)
student.stu(2,'Sagar',85)
# Out:
# stu id: 1
# stu name: Sonali
# stu marks: 80
# stu id: 2
# stu name: Sagar
# stu marks: 85

# %% [markdown]
# ## 1.Load data set and perform all da visualisation graphs.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('CAR DETAILS FROM CAR DEKHO (1).csv')
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
sns.barplot(y='year',x='fuel',data=df)
# Out:
# <Axes: xlabel='fuel', ylabel='year'>

# %%
sns.displot(df['fuel'])

# %%
sns.boxplot(x='year',y='km_driven',data=df)
# Out:
# <Axes: xlabel='year', ylabel='km_driven'>

# %%
sns.pairplot(data=df)

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
sns.scatterplot(x='fuel',y='selling_price',data=df)
# Out:
# <Axes: xlabel='fuel', ylabel='selling_price'>

# %% [markdown]
# ## 3.Explain type of Inheritance And perform Single inheritance example.
#
# ### Inheritance:-
#      1. Single Inheritance
#
#      2. Multiple Imheritance
#
#      3. Multilevel Inheritance

# %%
#1.Single Inheritance:-
class clg:
    def info1(self,cname,city):
      print('clg name:',cname)
      print('clg city:',city)
class student(clg):
    def info2(self,id,name,year):
      print('student id:',id)
      print('student name:',name)
      print('student year:',year)
stu=student()
stu.info1('Pcfscs','Smbhajinagar')
stu.info2(1,'Achal','3yr')
# Out:
# clg name: Pcfscs
# clg city: Smbhajinagar
# student id: 1
# student name: Achal
# student year: 3yr

# %% [markdown]
# ## 4.Explain and perform  Built in Data Types in python.
# ### Built in Data Types:-
#          1.List
#
#          2. Tuple
#
#          3.Set
#
#          4.Dictionart(dict)

# %%
#1.List:= it is declered in ([]) Square braket.
#it allow all type of data
#or it is mutable
a=[1,2,3,4,5.6,'abcd']
print(type(a))
print(a)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5.6, 'abcd']

# %%
#2.Tuple:-it is declered in() paranthesis.
#it is immutable
a=(1,2,3,4,5,6.0,'abcd')
print(type(a))
print(a)
# Out:
# <class 'tuple'>
# (1, 2, 3, 4, 5, 6.0, 'abcd')

# %%
#Set:- it is declered in ({})
#it is mutable or immutable
# it can be add or remove elements
a={1,2,3,4,5.3,'abcd'}
print(type(a))
print(a)
# Out:
# <class 'set'>
# {1, 2, 3, 4, 5.3, 'abcd'}

# %%
#Dict:-it is declered in ({})
#it is immutable
a={'name':'ram','age':23}
print(type(a))
print(a)
# Out:
# <class 'dict'>
# {'name': 'ram', 'age': 23}

# %% [markdown]
# ## 7.Compare K-means and KNN Algorithms.
# ###  k-Means:-
#      K is a Group of Number of Clusters.
#      Unsupervised Machine Learning algorithm
#      It perform division of object into cluster
# ### KNN :-
#      K-nearest neighber algorithm
#      It is Supervised Machine Learning algorithm.
#      It perform classifiction and regression dataset

# %% [markdown]
# ## 8.What is SQL, Explain DDL,DML,TCL,DQL command in sql.
# ### SQL:- Structured Ouery Language
# #### DDL:- Data defination language
#     Commands:- Create, Alter,Drop
# #### DML:- Data Manipulation Language
#     commands:- Select,Insert,Delete,Update

# %% [markdown]
# ## 9.What are the constraint use in SQL?
# ## Constraint:-
#     1.Primary Key
#     2.Foriegn key
#     3.Unique key
#     4.Not Null
#     5.Check
#     6.Default
