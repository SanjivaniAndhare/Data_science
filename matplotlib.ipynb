# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
x=[2,4,6,8]
y=[9,7,4,2]
plt.plot(x,y)
plt.show()

# %%
x=[4,6,8,9]
y=[2,5,6,7]
plt.plot(x,y)
plt.show()

# %%
x=[4,6,8,10]
y=[12,14,16,18]
plt.bar(x,y)
plt.show()

# %%
x=[2,5,6,4]
y=[8,10,12,6]
plt.plot(x,y)
plt.show()

# %%
x=[2,5,6,4]
y=[8,10,12,6]
plt.scatter(x,y)
plt.show()

# %%
y=[9,7,4,2]
plt.hist(y)
plt.show()

# %%
y=[8,9,10]
plt.hist(y)
plt.show()

# %%
x=[5,7,9,11]
plt.pie(x)
plt.show()

# %%
x=[1,2,3]
plt.hist(x)
plt.show()

# %%
x=[1.7,1.9,2.4,3.5,4.1,4.9,5.8]
y=[5,6,4,8,2,9,12]
plt.scatter(x,y)
plt.show()
