# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
db=pd.read_csv("heart_disease_dataset.csv")
db
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0     75  Female          228             119          66  Current
# 1     48    Male          204             165          62  Current
# 2     53    Male          234              91          67    Never
# 3     69  Female          192              90          72  Current
# 4     62  Female          172             163          93    Never
# ..   ...     ...          ...             ...         ...      ...
# 995   56  Female          269             111          86    Never
# 996   78  Female          334             145          76    Never
# 997   79    Male          151             179          81    Never
# 998   60  Female          326             151          68   Former
# 999   53    Male          226             116          82  Current
#
#     Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 0            Heavy               1             No       No     Yes
# ...

# %%
db.dtypes
# Out:
# Age                         int64
# Gender                     object
# Cholesterol                 int64
# Blood Pressure              int64
# Heart Rate                  int64
# Smoking                    object
# Alcohol Intake             object
# Exercise Hours              int64
# Family History             object
# Diabetes                   object
# Obesity                    object
# Stress Level                int64
# Blood Sugar                 int64
# Exercise Induced Angina    object
# Chest Pain Type            object
# Heart Disease               int64
# dtype: object

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   int64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           660 non-null    object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
# ...

# %%
db.describe()
# Out:
#                Age  Cholesterol  Blood Pressure   Heart Rate  Exercise Hours  \
# count  1000.000000  1000.000000       1000.0000  1000.000000     1000.000000
# mean     52.293000   249.939000        135.2810    79.204000        4.529000
# std      15.727126    57.914673         26.3883    11.486092        2.934241
# min      25.000000   150.000000         90.0000    60.000000        0.000000
# 25%      39.000000   200.000000        112.7500    70.000000        2.000000
# 50%      52.000000   248.000000        136.0000    79.000000        4.500000
# 75%      66.000000   299.000000        159.0000    89.000000        7.000000
# max      79.000000   349.000000        179.0000    99.000000        9.000000
#
#        Stress Level  Blood Sugar  Heart Disease
# count   1000.000000  1000.000000    1000.000000
# mean       5.646000   134.941000       0.392000
# std        2.831024    36.699624       0.488441
# min        1.000000    70.000000       0.000000
# ...

# %%
db.shape
# Out:
# (1000, 16)

# %%
dt["Age"].value_counts()
# Out:
# Age
# 37    31
# 49    28
# 76    26
# 48    26
# 26    26
# 59    23
# 51    23
# 64    22
# 42    22
# 69    21
# 70    21
# 63    21
# 66    21
# 46    21
# 41    20
# 68    20
# 75    20
# 27    20
# 54    20
# 61    19
# 58    18
# 40    18
# 36    18
# 55    18
# 62    18
# 53    18
# 52    17
# 50    17
# 71    17
# 25    17
# 73    17
# 28    17
# 74    17
# 79    17
# 43    16
# 44    16
# 78    16
# 34    16
# 35    16
# 72    16
# 32    15
# 56    15
# 77    15
# 67    15
# 45    15
# 38    15
# 33    14
# 65    14
# 39    14
# 31    14
# 47    14
# 60    13
# 30    12
# 57    12
# 29    12
# Name: count, dtype: int64

# %%
dt["Heart Rate"].value_counts()
# Out:
# Heart Rate
# 69    33
# 62    32
# 75    32
# 82    32
# 99    31
# 72    31
# 63    31
# 81    30
# 71    30
# 89    29
# 97    29
# 70    29
# 76    29
# 94    27
# 87    27
# 65    27
# 77    27
# 83    26
# 80    25
# 98    25
# 61    25
# 74    25
# 92    25
# 78    24
# 86    23
# 95    23
# 67    23
# 79    22
# 73    22
# 93    22
# 64    22
# 90    21
# 85    20
# 68    20
# 91    19
# 84    19
# 60    19
# 96    15
# 88    15
# 66    14
# Name: count, dtype: int64

# %%
db.head()
# Out:
#    Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0   75  Female          228             119          66  Current
# 1   48    Male          204             165          62  Current
# 2   53    Male          234              91          67    Never
# 3   69  Female          192              90          72  Current
# 4   62  Female          172             163          93    Never
#
#   Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 0          Heavy               1             No       No     Yes
# 1            NaN               5             No       No      No
# 2          Heavy               3            Yes       No     Yes
# 3            NaN               4             No      Yes      No
# 4            NaN               6             No      Yes      No
#
#    Stress Level  Blood Sugar Exercise Induced Angina   Chest Pain Type  \
# 0             8          119                     Yes   Atypical Angina
# ...

# %%
features=dt.iloc[:,:-1]
target= dt.iloc[:,-1]

# %%
target
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 995    1
# 996    1
# 997    0
# 998    1
# 999    1
# Name: Heart Disease, Length: 1000, dtype: int64

# %%
features
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0     75  Female          228             119          66  Current
# 1     48    Male          204             165          62  Current
# 2     53    Male          234              91          67    Never
# 3     69  Female          192              90          72  Current
# 4     62  Female          172             163          93    Never
# ..   ...     ...          ...             ...         ...      ...
# 995   56  Female          269             111          86    Never
# 996   78  Female          334             145          76    Never
# 997   79    Male          151             179          81    Never
# 998   60  Female          326             151          68   Former
# 999   53    Male          226             116          82  Current
#
#     Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 0            Heavy               1             No       No     Yes
# ...

# %%
features["Age"].replace("?",np.nan,inplace=True)
features["Heart Rate"].replace("?",np.nan,inplace=True)

features["Age"]=features["Age"].astype("float64")
features["Heart Rate"]=features["Heart Rate"].astype("float64")

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(missing_values = np.nan, strategy = "mean")
features[["Age","Heart Rate"]] = si.fit_transform(features[["Age","Heart Rate"]])

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   float64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   float64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           660 non-null    object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
# ...

# %%
target.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Heart Disease
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   int64
# dtypes: int64(1)
# memory usage: 7.9 KB

# %%
sns.boxplot(data=features, x=target)
# Out:
# <Axes: xlabel='Heart Disease'>

# %%
sns.boxplot(data=features, x=target, y="Gender")
plt.grid()
